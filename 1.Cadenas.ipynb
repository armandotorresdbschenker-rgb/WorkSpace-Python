# %%
print(r"c:\nombre\directory")
# Out:
# c:\nombre\directory

# %%
cadena1 = "moderno"
cadena2 = "Python"
cadena3 = "de programacion"
cadena4 = "es un lenguaje"

#completa el ejercicio
cadena5 = cadena2 + " "+ cadena4 + " "+  cadena3 + " " + cadena1
print(cadena5)
# Out:
# Python es un lenguaje de programacion moderno

# %% [markdown]
# Indices y Slicing

# %%
palabra = "Python"

# %%
print(palabra[0])
print(palabra[1])
print(palabra[2])
print(palabra[3])
# Out:
# P
# y
# t
# h

# %%
print(palabra[0:2])
print(palabra[2:])
print(palabra[:2])
print(palabra[:])
print(palabra[:2] + palabra[2:])
# Out:
# Py
# thon
# Py
# Python
# Python

# %%
palabra[-2:]
# Out:
# 'on'

# %%
palabra[-6:]
# Out:
# 'Python'

# %%
palabra[:99]
# Out:
# 'Python'

# %%
palabra = "N" + palabra[0:]
palabra
# Out:
# 'NPython'

# %%
palabra = "Python"
palabra = "N" + palabra[1:]
palabra
# Out:
# 'Nython'

# %%
len(palabra)
# Out:
# 6

# %%
palabra[:len(palabra)]
# Out:
# 'Nython'

# %%
#ejercicio
cadena_corrputa = "airotsiH,6.7,aícraG nómaR"

# %%
cadena_volteada = cadena_corrputa[::-1]
cadena_volteada
# Out:
# 'Ramón García,7.6,Historia'

# %%
nombre = cadena_volteada[:5]
apellido = cadena_volteada[6:12]
nota = cadena_volteada[13:16]
materia = cadena_volteada[17:]
print(nombre + " " + apellido )
print(nota)
print(materia)
# Out:
# Ramón García
# 7.6
# Historia

# %%
cadena_formateada = nombre + " "+ apellido +" ha sacado un "+ nota  + " en " + materia
cadena_formateada
# Out:
# 'Ramón García ha sacado un 7.6 en Historia'
