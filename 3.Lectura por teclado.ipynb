# %%
valor = input()

# %%
valor
# Out:
# 'algo'

# %%
valor = input("Introduce un valor")

# %%
valor
# Out:
# '100'

# %%
valor = input("Introduce un numero entero: ")

# %%
valor
# Out:
# '10'

# %%
valor = int(valor)

# %%
valor
# Out:
# 10

# %%
valor + 100
# Out:
# 110

# %%
valor = input("Introduce un numero entero: ")

# %%
valor = float(valor)

# %%
valor
# Out:
# 3.14

# %%
valor + 10
# Out:
# 13.14
