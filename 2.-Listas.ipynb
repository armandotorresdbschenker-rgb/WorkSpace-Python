# %% [markdown]
# Listas

# %%
numeros = [1,2,3,4]
datos = [4,"una cadena", -15, 3.14,"Otra cadena"]

# %%
datos[0]
# Out:
# 4

# %%
datos[-1]
# Out:
# 'Otra cadena'

# %%
datos[-2]
# Out:
# 3.14

# %%
datos[-2:]
# Out:
# [3.14, 'Otra cadena']

# %%
numeros + [5,6,7,8]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
pares = [0,2,4,5,8,10]

# %%
pares[3] = 6

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
pares.append(12)

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 10, 12]

# %%
pares.append(7*2)

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
letras = ['a','b','c','d','e','f']
letras
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
letras[:3]
# Out:
# ['a', 'b', 'c']

# %%
letras[:3] = ['A','B','C']
letras
# Out:
# ['A', 'B', 'C', 'd', 'e', 'f']

# %%
letras[:3] = []

# %%
letras
# Out:
# ['d', 'e', 'f']

# %%
letras= []
letras
# Out:
# []

# %%
len(letras)
# Out:
# 0

# %%
len(pares)
# Out:
# 8

# %%
a = [1,2,3]
b = [4,5,6]
c = [7,8,9]
r = [a,b,c]
r
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
r[0]
# Out:
# [1, 2, 3]

# %%
r[-1]
# Out:
# [7, 8, 9]

# %%
r[0][0]
# Out:
# 1

# %%
r[1][1]
# Out:
# 5

# %%
r[2][2]
# Out:
# 9

# %%
r[-1][-1]
# Out:
# 9

# %%
#Ejercicio
lista1 = [1,12,123]
lista2 = ["Hola","mundo"]

lista1.append(1234)
lista1.append("Bye")
lista2.append("Adios")
lista2.append(1234)
print(lista1)
print(lista2)
# Out:
# [1, 12, 123, 1234, 'Bye']
# ['Hola', 'mundo', 'Adios', 1234]

# %%
lista3 = lista1[:-1]
lista3
# Out:
# [1, 12, 123, 1234]

# %%
lista4 = lista2[1:-1]
lista4
# Out:
# ['mundo', 'Adios']

# %%
lista5 = lista4 + lista3
lista5
# Out:
# ['mundo', 'Adios', 1, 12, 123, 1234]
